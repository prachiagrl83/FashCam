# %%
#https://www.kaggle.com/code/tahmidhasansakib/visual-product-recommendation-system-using-cnn
#!pip install tensorflow

# %%
#pip install opencv-python

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.preprocessing import image
import cv2
import pickle
import warnings
warnings.filterwarnings("ignore")
from tensorflow.keras.models import Sequential, model_from_json


from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.applications import DenseNet121

# %%
df = pd.read_csv("E:/Data Science Bootcamp/Final Project/Cloths_small_dataset/new_dataset.csv",error_bad_lines=False)
df['image_jpg'] = df.apply(lambda x: str(x['image']) + ".jpg", axis=1)
df = df.reset_index(drop=True)
print(df.shape)
df.head(5)
# Out:
# (4689, 3)
#                                   image    label  \
# 0  00003aeb-ace5-43bf-9a0c-dc31a03e9cd2  T-Shirt
# 1  000d31f6-44b5-4758-8d86-c4fcfb234392   Hoodie
# 2  001068a8-86c3-4029-a9d9-1e27015e7e64     Polo
# 3  00143901-a14c-4600-960f-7747b4a3a8cd    Shirt
# 4  00149032-3dd6-426e-9bc0-d53032536a42  Outwear
#
#                                   image_jpg
# 0  00003aeb-ace5-43bf-9a0c-dc31a03e9cd2.jpg
# 1  000d31f6-44b5-4758-8d86-c4fcfb234392.jpg
# 2  001068a8-86c3-4029-a9d9-1e27015e7e64.jpg
# 3  00143901-a14c-4600-960f-7747b4a3a8cd.jpg
# 4  00149032-3dd6-426e-9bc0-d53032536a42.jpg

# %%
Dataframe = pd.DataFrame({
    'image_name': df['image_jpg'],
    'type': df['label']
})

# total number of entries in the dataframe
total_row = len(Dataframe)
print('total row count: ', total_row)

Dataframe.head(10)
# Out:
# total row count:  4689
#                                  image_name        type
# 0  00003aeb-ace5-43bf-9a0c-dc31a03e9cd2.jpg     T-Shirt
# 1  000d31f6-44b5-4758-8d86-c4fcfb234392.jpg      Hoodie
# 2  001068a8-86c3-4029-a9d9-1e27015e7e64.jpg        Polo
# 3  00143901-a14c-4600-960f-7747b4a3a8cd.jpg       Shirt
# 4  00149032-3dd6-426e-9bc0-d53032536a42.jpg     Outwear
# 5  00208c77-ee58-4b63-bc1a-b9b3aa4f1be0.jpg     Outwear
# 6  0028956e-9962-46f0-ad45-2c42f8a59d94.jpg     Outwear
# 7  002e88c2-e0ce-4a4b-9670-eddc3d99accc.jpg  Undershirt
# 8  002eb5b8-6541-42a3-9596-0d94f7b866ae.jpg       Pants
# 9  00342aff-ba69-4cf2-ae62-e00680e9547a.jpg    Not sure

# %%
unique_types = Dataframe['type'].unique().tolist()
total_class = len(unique_types)
print(total_class)
print(unique_types)
print(unique_types[0])
print(unique_types.index(unique_types[0]))
Dataframe['number_types'] = Dataframe['type'].apply(lambda x: unique_types.index(x) if x in unique_types else 0)
Dataframe.head(10)
# Out:
# 20
# ['T-Shirt', 'Hoodie', 'Polo', 'Shirt', 'Outwear', 'Undershirt', 'Pants', 'Not sure', 'Longsleeve', 'Dress', 'Body', 'Blazer', 'Hat', 'Shorts', 'Shoes', 'Skirt', 'Other', 'Top', 'Blouse', 'Skip']
# T-Shirt
# 0
#                                  image_name        type  number_types
# 0  00003aeb-ace5-43bf-9a0c-dc31a03e9cd2.jpg     T-Shirt             0
# 1  000d31f6-44b5-4758-8d86-c4fcfb234392.jpg      Hoodie             1
# 2  001068a8-86c3-4029-a9d9-1e27015e7e64.jpg        Polo             2
# 3  00143901-a14c-4600-960f-7747b4a3a8cd.jpg       Shirt             3
# 4  00149032-3dd6-426e-9bc0-d53032536a42.jpg     Outwear             4
# 5  00208c77-ee58-4b63-bc1a-b9b3aa4f1be0.jpg     Outwear             4
# 6  0028956e-9962-46f0-ad45-2c42f8a59d94.jpg     Outwear             4
# 7  002e88c2-e0ce-4a4b-9670-eddc3d99accc.jpg  Undershirt             5
# 8  002eb5b8-6541-42a3-9596-0d94f7b866ae.jpg       Pants             6
# 9  00342aff-ba69-4cf2-ae62-e00680e9547a.jpg    Not sure             7

# %%
Dataframe['type'].value_counts()
# Out:
# T-Shirt       878
# Longsleeve    598
# Pants         596
# Shoes         377
# Shirt         338
# Dress         312
# Shorts        277
# Outwear       263
# Not sure      201
# Hat           148
# Skirt         134
# Polo          107
# Undershirt     97
# Blazer         93
# Hoodie         89
# Other          59
# Body           58
# Top            38
# Blouse         20
# Skip            6
# Name: type, dtype: int64

# %%
plt.figure(figsize=(20,5))
Dataframe['type'].value_counts().plot(kind='bar',x='type',y='image_name')
plt.show()

# %%
import os
DATASET_PATH = "E:/Data Science Bootcamp/Final Project/Cloths_small_dataset/images/"
list_directory = os.listdir(DATASET_PATH)
# each time directory files gets reordered. That's why needed to find where images folder is.
index=0
for i in range (len(list_directory)):
    if list_directory[i]=="images":
        index=i
        break
def getData(start,stop):
    x_data = []
    y_data = []
    #start = 0 #setting start parameter
    #stop = int(0.001*total_row) #setting stop parameter 
    
    for i in range(start, stop): 
        Image_path=DATASET_PATH+list_directory[index]+"/"+Dataframe.loc[i,'image_name']
        #print(Dataframe.loc[i,'image_name'])
        image = cv2.imread(Image_path,cv2.IMREAD_GRAYSCALE)
        try:
            resized_img = cv2.resize(image, dsize=(28, 28))
        except:
            print("Rejected Image: "+Dataframe.loc[i,'image_name'])
            continue
        x_data.append(resized_img) 
        y_values = Dataframe.loc[i,'number_types'] # earlier it was type
        y_data.append(y_values)
                
    return x_data, y_data

# %%
X=[]
Y=[]
# for now start=0,stop=(0.001*total_row)
# total_row=count of rows in augmented data frame
start = 0
stop = int(0.001*total_row) # testing with 0.1% image of the dataset
X,Y=getData(start,stop)

print(type(X))
print(X[0])
plt.title(unique_types[Y[0]])
plt.imshow(X[0])
# Out:
# <class 'list'>
# [[ 49  47  35  32  44  50  54  53  56  55  54  56  54  56  56  56  57  50
#    52  53  49  54  50  44  43  37  30  28]
#  [ 52  52  52  52  56  55  58  58  58  58  59  57  56  58  57  57  57  56
#    55  54  56  50  53  51  54  47  49  44]
#  [ 52  51  35  54  55  57  59  61  58  58  61  58  60  58  57  60  58  57
#    55  59  59  57  53  55  57  53  45  51]
#  [ 51  48  53  57  59  62  62  62  61  59  58  60  62  59  61  58  59  61
#    56  57  60  58  58  53  52  53  49  51]
#  [ 49  54  57  61  62  62  64  65  64  63  63  65  65  64  65  60  64  62
#    62  67  64  61  57  61  57  55  56  51]
#  [ 54  60  62  62  63  63  64  64  63  65  68  66  58  63  63  69  62  63
#    64  53  63  61  60  59  57  56  55  53]
#  [ 60  66  66  65  66  64  67  68  69  66  70  66  64  59  69  64  59  67
#    65  70  64  61  58  61  60  49  56  58]
#  [ 67  67  67  66  68  68  67  70  68  66  70  69  62  64  66  61  60  65
#    74  65  60  55  67  68  58  51  58  57]
#  [ 68  68  69  68  68  68  69  69 160 157 163 158 122 189 131 171 159 177
#   135  54  58  57  65  55  60  52  59  54]
#  [ 68  69  71  71  72 176 170 160 166 158 163 168 183 190 125 146 156 157
#   182 172 172 196  52  57  55  54  62  60]
#  [ 72  76 157 159 177 173 167 175 145 165 160 166 170 175 198 185 174 197
#   203 191 160 142 152 136 168  47  57  65]
#  [ 72 151 140 156 166 180 199 159 148 151 142 150 156 147 151 142 137 182
#   145 148 146 157 185 176 185 198  45  56]
#  [ 73  87 193 191 182 158 170 174 190 188 189 158 168 117 110 189  54  92
#    79 151 169 188 198 186 181 129 155 155]
#  [ 76  76 171 167 176 130 147 171 178 169 147 144 109 156 149 165 180  74
#    76 129 139 139 150 169 170 200 181  58]
#  [ 77  77  93  75  85 174 169 211 182 173 163 134 154  89  83 135 162 175
#   172 165 196 198 197 213  51  60 181  72]
#  [ 77  70  78  82  85 154 209 147 202 218 117 191 191  96  84  85 156 173
#    73 162 188 193 197 198  56  54  62  60]
#  [ 80  67  81  78  89 149 191 180 200 180 129 185 195 159 168 193 180 150
#   160 172 162 178 198 208  57  61  56  72]
#  [ 76  62  81  80 192 162 194 184 189 194 112  96 140 170 153 156 165 172
#   186 162 149 157 176 213  47  78  48  76]
#  [ 68  77  75  87 188 192 179 188 182 125 111 109  95 116 171 190 170 161
#   157 180 197 179 183 187  83  82  71  74]
#  [ 68  76  86  74 204 212 149 175 177 173 188 113 169  35  15  20  47 158
#   148 183 178 180 176 188  90  81  76  83]
#  [ 57  75  83  99 177 193 137 189 205 144 168 177 177 186 125 177 195 160
#   183 178 178 182 196 180 193  66  54  80]
#  [ 58  52  63  69 153 184 138 201 187 174 186 191 197 204 189 180 187 169
#   167 183 171 174 176 193 210  56  65  46]
#  [ 87  98  76 101 143 188 181 220 185 206 181 194 206 198 172 185 184 189
#   181 192 182 179 190 196 197  42  70  69]
#  [ 92  55  98 223 120 194 183 210 185 204 187 195 209 189 181 183 191 193
#   190 186 191 181 184 195 157 212  56  57]
#  [101 108  69 207 124 189 213 201 204 190 178 205 212 210 169 203 195 195
#   187 176 192 184 166 191 150 182  59  63]
#  [ 91  93  88 100 103  86  74  56  92 105 101 104  97 105  57  91 126 181
#   197 171 192 179 186 208 173 203  70  66]
#  [ 69  69  62  74  76  72  76  87  39  68  77  69  67  75  62  76  59  60
#    86  86  82  73  76  70  65  65  68  65]
#  [ 73  78  89  77  85  73  76  83  73  75  72  67  70  72  51  62  60  64
#    60  50  50  49  44  14  38  28  19  11]]

# %%
X = np.array(X).reshape(-1, 28,28,1)
Y = np.array(Y)
len(Y)
# Out:
# 4

# %%
X = X/255.0
len(X)
# Out:
# 4

# %%
Y = Y.reshape(len(X),)
Y
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
print(type(X))
print(X.shape)
print(Y.shape)
print(X[0])
print(Y[0])
# Out:
# <class 'numpy.ndarray'>
# (4, 28, 28, 1)
# (4,)
# [[[0.19215686]
#   [0.18431373]
#   [0.1372549 ]
#   [0.1254902 ]
#   [0.17254902]
#   [0.19607843]
#   [0.21176471]
#   [0.20784314]
#   [0.21960784]
#   [0.21568627]
#   [0.21176471]
#   [0.21960784]
#   [0.21176471]
#   [0.21960784]
#   [0.21960784]
#   [0.21960784]
#   [0.22352941]
#   [0.19607843]
#   [0.20392157]
#   [0.20784314]
#   [0.19215686]
#   [0.21176471]
#   [0.19607843]
#   [0.17254902]
#   [0.16862745]
#   [0.14509804]
#   [0.11764706]
#   [0.10980392]]
#
#  [[0.20392157]
#   [0.20392157]
#   [0.20392157]
#   [0.20392157]
#   [0.21960784]
#   [0.21568627]
#   [0.22745098]
#   [0.22745098]
#   [0.22745098]
#   [0.22745098]
#   [0.23137255]
#   [0.22352941]
#   [0.21960784]
#   [0.22745098]
#   [0.22352941]
#   [0.22352941]
#   [0.22352941]
#   [0.21960784]
#   [0.21568627]
#   [0.21176471]
#   [0.21960784]
#   [0.19607843]
#   [0.20784314]
#   [0.2       ]
#   [0.21176471]
#   [0.18431373]
#   [0.19215686]
#   [0.17254902]]
#
#  [[0.20392157]
#   [0.2       ]
#   [0.1372549 ]
#   [0.21176471]
#   [0.21568627]
#   [0.22352941]
#   [0.23137255]
#   [0.23921569]
#   [0.22745098]
#   [0.22745098]
#   [0.23921569]
#   [0.22745098]
#   [0.23529412]
#   [0.22745098]
#   [0.22352941]
#   [0.23529412]
#   [0.22745098]
#   [0.22352941]
#   [0.21568627]
#   [0.23137255]
#   [0.23137255]
#   [0.22352941]
#   [0.20784314]
#   [0.21568627]
#   [0.22352941]
#   [0.20784314]
#   [0.17647059]
#   [0.2       ]]
#
#  [[0.2       ]
#   [0.18823529]
#   [0.20784314]
#   [0.22352941]
#   [0.23137255]
#   [0.24313725]
#   [0.24313725]
#   [0.24313725]
#   [0.23921569]
#   [0.23137255]
#   [0.22745098]
#   [0.23529412]
#   [0.24313725]
#   [0.23137255]
#   [0.23921569]
#   [0.22745098]
#   [0.23137255]
#   [0.23921569]
#   [0.21960784]
#   [0.22352941]
#   [0.23529412]
#   [0.22745098]
#   [0.22745098]
#   [0.20784314]
#   [0.20392157]
#   [0.20784314]
#   [0.19215686]
#   [0.2       ]]
#
#  [[0.19215686]
#   [0.21176471]
#   [0.22352941]
#   [0.23921569]
#   [0.24313725]
#   [0.24313725]
#   [0.25098039]
#   [0.25490196]
#   [0.25098039]
#   [0.24705882]
#   [0.24705882]
#   [0.25490196]
#   [0.25490196]
#   [0.25098039]
#   [0.25490196]
#   [0.23529412]
#   [0.25098039]
#   [0.24313725]
#   [0.24313725]
#   [0.2627451 ]
#   [0.25098039]
#   [0.23921569]
#   [0.22352941]
#   [0.23921569]
#   [0.22352941]
#   [0.21568627]
#   [0.21960784]
#   [0.2       ]]
#
#  [[0.21176471]
#   [0.23529412]
#   [0.24313725]
#   [0.24313725]
#   [0.24705882]
#   [0.24705882]
#   [0.25098039]
#   [0.25098039]
#   [0.24705882]
#   [0.25490196]
#   [0.26666667]
#   [0.25882353]
#   [0.22745098]
#   [0.24705882]
#   [0.24705882]
#   [0.27058824]
#   [0.24313725]
#   [0.24705882]
#   [0.25098039]
#   [0.20784314]
#   [0.24705882]
#   [0.23921569]
#   [0.23529412]
#   [0.23137255]
#   [0.22352941]
#   [0.21960784]
#   [0.21568627]
#   [0.20784314]]
#
#  [[0.23529412]
#   [0.25882353]
#   [0.25882353]
#   [0.25490196]
#   [0.25882353]
#   [0.25098039]
#   [0.2627451 ]
#   [0.26666667]
#   [0.27058824]
#   [0.25882353]
#   [0.2745098 ]
#   [0.25882353]
#   [0.25098039]
#   [0.23137255]
#   [0.27058824]
#   [0.25098039]
#   [0.23137255]
#   [0.2627451 ]
#   [0.25490196]
#   [0.2745098 ]
#   [0.25098039]
#   [0.23921569]
#   [0.22745098]
#   [0.23921569]
#   [0.23529412]
#   [0.19215686]
#   [0.21960784]
#   [0.22745098]]
#
#  [[0.2627451 ]
#   [0.2627451 ]
#   [0.2627451 ]
#   [0.25882353]
#   [0.26666667]
#   [0.26666667]
#   [0.2627451 ]
#   [0.2745098 ]
#   [0.26666667]
#   [0.25882353]
#   [0.2745098 ]
#   [0.27058824]
#   [0.24313725]
#   [0.25098039]
#   [0.25882353]
#   [0.23921569]
#   [0.23529412]
#   [0.25490196]
#   [0.29019608]
#   [0.25490196]
#   [0.23529412]
#   [0.21568627]
#   [0.2627451 ]
#   [0.26666667]
#   [0.22745098]
#   [0.2       ]
#   [0.22745098]
#   [0.22352941]]
#
#  [[0.26666667]
#   [0.26666667]
#   [0.27058824]
#   [0.26666667]
#   [0.26666667]
#   [0.26666667]
#   [0.27058824]
#   [0.27058824]
#   [0.62745098]
#   [0.61568627]
#   [0.63921569]
#   [0.61960784]
#   [0.47843137]
#   [0.74117647]
#   [0.51372549]
#   [0.67058824]
#   [0.62352941]
#   [0.69411765]
#   [0.52941176]
#   [0.21176471]
#   [0.22745098]
#   [0.22352941]
#   [0.25490196]
#   [0.21568627]
#   [0.23529412]
#   [0.20392157]
#   [0.23137255]
#   [0.21176471]]
#
#  [[0.26666667]
#   [0.27058824]
#   [0.27843137]
#   [0.27843137]
#   [0.28235294]
#   [0.69019608]
#   [0.66666667]
#   [0.62745098]
#   [0.65098039]
#   [0.61960784]
#   [0.63921569]
#   [0.65882353]
#   [0.71764706]
#   [0.74509804]
#   [0.49019608]
#   [0.57254902]
#   [0.61176471]
#   [0.61568627]
#   [0.71372549]
#   [0.6745098 ]
#   [0.6745098 ]
#   [0.76862745]
#   [0.20392157]
#   [0.22352941]
#   [0.21568627]
#   [0.21176471]
#   [0.24313725]
#   [0.23529412]]
#
#  [[0.28235294]
#   [0.29803922]
#   [0.61568627]
#   [0.62352941]
#   [0.69411765]
#   [0.67843137]
#   [0.65490196]
#   [0.68627451]
#   [0.56862745]
#   [0.64705882]
#   [0.62745098]
#   [0.65098039]
#   [0.66666667]
#   [0.68627451]
#   [0.77647059]
#   [0.7254902 ]
#   [0.68235294]
#   [0.77254902]
#   [0.79607843]
#   [0.74901961]
#   [0.62745098]
#   [0.55686275]
#   [0.59607843]
#   [0.53333333]
#   [0.65882353]
#   [0.18431373]
#   [0.22352941]
#   [0.25490196]]
#
#  [[0.28235294]
#   [0.59215686]
#   [0.54901961]
#   [0.61176471]
#   [0.65098039]
#   [0.70588235]
#   [0.78039216]
#   [0.62352941]
#   [0.58039216]
#   [0.59215686]
#   [0.55686275]
#   [0.58823529]
#   [0.61176471]
#   [0.57647059]
#   [0.59215686]
#   [0.55686275]
#   [0.5372549 ]
#   [0.71372549]
#   [0.56862745]
#   [0.58039216]
#   [0.57254902]
#   [0.61568627]
#   [0.7254902 ]
#   [0.69019608]
#   [0.7254902 ]
#   [0.77647059]
#   [0.17647059]
#   [0.21960784]]
#
#  [[0.28627451]
#   [0.34117647]
#   [0.75686275]
#   [0.74901961]
#   [0.71372549]
#   [0.61960784]
#   [0.66666667]
#   [0.68235294]
#   [0.74509804]
#   [0.7372549 ]
#   [0.74117647]
#   [0.61960784]
#   [0.65882353]
#   [0.45882353]
#   [0.43137255]
#   [0.74117647]
#   [0.21176471]
#   [0.36078431]
#   [0.30980392]
#   [0.59215686]
#   [0.6627451 ]
#   [0.7372549 ]
#   [0.77647059]
#   [0.72941176]
#   [0.70980392]
#   [0.50588235]
#   [0.60784314]
#   [0.60784314]]
#
#  [[0.29803922]
#   [0.29803922]
#   [0.67058824]
#   [0.65490196]
#   [0.69019608]
#   [0.50980392]
#   [0.57647059]
#   [0.67058824]
#   [0.69803922]
#   [0.6627451 ]
#   [0.57647059]
#   [0.56470588]
#   [0.42745098]
#   [0.61176471]
#   [0.58431373]
#   [0.64705882]
#   [0.70588235]
#   [0.29019608]
#   [0.29803922]
#   [0.50588235]
#   [0.54509804]
#   [0.54509804]
#   [0.58823529]
#   [0.6627451 ]
#   [0.66666667]
#   [0.78431373]
#   [0.70980392]
#   [0.22745098]]
#
#  [[0.30196078]
#   [0.30196078]
#   [0.36470588]
#   [0.29411765]
#   [0.33333333]
#   [0.68235294]
#   [0.6627451 ]
#   [0.82745098]
#   [0.71372549]
#   [0.67843137]
#   [0.63921569]
#   [0.5254902 ]
#   [0.60392157]
#   [0.34901961]
#   [0.3254902 ]
#   [0.52941176]
#   [0.63529412]
#   [0.68627451]
#   [0.6745098 ]
#   [0.64705882]
#   [0.76862745]
#   [0.77647059]
#   [0.77254902]
#   [0.83529412]
#   [0.2       ]
#   [0.23529412]
#   [0.70980392]
#   [0.28235294]]
#
#  [[0.30196078]
#   [0.2745098 ]
#   [0.30588235]
#   [0.32156863]
#   [0.33333333]
#   [0.60392157]
#   [0.81960784]
#   [0.57647059]
#   [0.79215686]
#   [0.85490196]
#   [0.45882353]
#   [0.74901961]
#   [0.74901961]
#   [0.37647059]
#   [0.32941176]
#   [0.33333333]
#   [0.61176471]
#   [0.67843137]
#   [0.28627451]
#   [0.63529412]
#   [0.7372549 ]
#   [0.75686275]
#   [0.77254902]
#   [0.77647059]
#   [0.21960784]
#   [0.21176471]
#   [0.24313725]
#   [0.23529412]]
#
#  [[0.31372549]
#   [0.2627451 ]
#   [0.31764706]
#   [0.30588235]
#   [0.34901961]
#   [0.58431373]
#   [0.74901961]
#   [0.70588235]
#   [0.78431373]
#   [0.70588235]
#   [0.50588235]
#   [0.7254902 ]
#   [0.76470588]
#   [0.62352941]
#   [0.65882353]
#   [0.75686275]
#   [0.70588235]
#   [0.58823529]
#   [0.62745098]
#   [0.6745098 ]
#   [0.63529412]
#   [0.69803922]
#   [0.77647059]
#   [0.81568627]
#   [0.22352941]
#   [0.23921569]
#   [0.21960784]
#   [0.28235294]]
#
#  [[0.29803922]
#   [0.24313725]
#   [0.31764706]
#   [0.31372549]
#   [0.75294118]
#   [0.63529412]
#   [0.76078431]
#   [0.72156863]
#   [0.74117647]
#   [0.76078431]
#   [0.43921569]
#   [0.37647059]
#   [0.54901961]
#   [0.66666667]
#   [0.6       ]
#   [0.61176471]
#   [0.64705882]
#   [0.6745098 ]
#   [0.72941176]
#   [0.63529412]
#   [0.58431373]
#   [0.61568627]
#   [0.69019608]
#   [0.83529412]
#   [0.18431373]
#   [0.30588235]
#   [0.18823529]
#   [0.29803922]]
#
#  [[0.26666667]
#   [0.30196078]
#   [0.29411765]
#   [0.34117647]
#   [0.7372549 ]
#   [0.75294118]
#   [0.70196078]
#   [0.7372549 ]
#   [0.71372549]
#   [0.49019608]
#   [0.43529412]
#   [0.42745098]
#   [0.37254902]
#   [0.45490196]
#   [0.67058824]
#   [0.74509804]
#   [0.66666667]
#   [0.63137255]
#   [0.61568627]
#   [0.70588235]
#   [0.77254902]
#   [0.70196078]
#   [0.71764706]
#   [0.73333333]
#   [0.3254902 ]
#   [0.32156863]
#   [0.27843137]
#   [0.29019608]]
#
#  [[0.26666667]
#   [0.29803922]
#   [0.3372549 ]
#   [0.29019608]
#   [0.8       ]
#   [0.83137255]
#   [0.58431373]
#   [0.68627451]
#   [0.69411765]
#   [0.67843137]
#   [0.7372549 ]
#   [0.44313725]
#   [0.6627451 ]
#   [0.1372549 ]
#   [0.05882353]
#   [0.07843137]
#   [0.18431373]
#   [0.61960784]
#   [0.58039216]
#   [0.71764706]
#   [0.69803922]
#   [0.70588235]
#   [0.69019608]
#   [0.7372549 ]
#   [0.35294118]
#   [0.31764706]
#   [0.29803922]
#   [0.3254902 ]]
#
#  [[0.22352941]
#   [0.29411765]
#   [0.3254902 ]
#   [0.38823529]
#   [0.69411765]
#   [0.75686275]
#   [0.5372549 ]
#   [0.74117647]
#   [0.80392157]
#   [0.56470588]
#   [0.65882353]
#   [0.69411765]
#   [0.69411765]
#   [0.72941176]
#   [0.49019608]
#   [0.69411765]
#   [0.76470588]
#   [0.62745098]
#   [0.71764706]
#   [0.69803922]
#   [0.69803922]
#   [0.71372549]
#   [0.76862745]
#   [0.70588235]
#   [0.75686275]
#   [0.25882353]
#   [0.21176471]
#   [0.31372549]]
#
#  [[0.22745098]
#   [0.20392157]
#   [0.24705882]
#   [0.27058824]
#   [0.6       ]
#   [0.72156863]
#   [0.54117647]
#   [0.78823529]
#   [0.73333333]
#   [0.68235294]
#   [0.72941176]
#   [0.74901961]
#   [0.77254902]
#   [0.8       ]
#   [0.74117647]
#   [0.70588235]
#   [0.73333333]
#   [0.6627451 ]
#   [0.65490196]
#   [0.71764706]
#   [0.67058824]
#   [0.68235294]
#   [0.69019608]
#   [0.75686275]
#   [0.82352941]
#   [0.21960784]
#   [0.25490196]
#   [0.18039216]]
#
#  [[0.34117647]
#   [0.38431373]
#   [0.29803922]
#   [0.39607843]
#   [0.56078431]
#   [0.7372549 ]
#   [0.70980392]
#   [0.8627451 ]
#   [0.7254902 ]
#   [0.80784314]
#   [0.70980392]
#   [0.76078431]
#   [0.80784314]
#   [0.77647059]
#   [0.6745098 ]
#   [0.7254902 ]
#   [0.72156863]
#   [0.74117647]
#   [0.70980392]
#   [0.75294118]
#   [0.71372549]
#   [0.70196078]
#   [0.74509804]
#   [0.76862745]
#   [0.77254902]
#   [0.16470588]
#   [0.2745098 ]
#   [0.27058824]]
#
#  [[0.36078431]
#   [0.21568627]
#   [0.38431373]
#   [0.8745098 ]
#   [0.47058824]
#   [0.76078431]
#   [0.71764706]
#   [0.82352941]
#   [0.7254902 ]
#   [0.8       ]
#   [0.73333333]
#   [0.76470588]
#   [0.81960784]
#   [0.74117647]
#   [0.70980392]
#   [0.71764706]
#   [0.74901961]
#   [0.75686275]
#   [0.74509804]
#   [0.72941176]
#   [0.74901961]
#   [0.70980392]
#   [0.72156863]
#   [0.76470588]
#   [0.61568627]
#   [0.83137255]
#   [0.21960784]
#   [0.22352941]]
#
#  [[0.39607843]
#   [0.42352941]
#   [0.27058824]
#   [0.81176471]
#   [0.48627451]
#   [0.74117647]
#   [0.83529412]
#   [0.78823529]
#   [0.8       ]
#   [0.74509804]
#   [0.69803922]
#   [0.80392157]
#   [0.83137255]
#   [0.82352941]
#   [0.6627451 ]
#   [0.79607843]
#   [0.76470588]
#   [0.76470588]
#   [0.73333333]
#   [0.69019608]
#   [0.75294118]
#   [0.72156863]
#   [0.65098039]
#   [0.74901961]
#   [0.58823529]
#   [0.71372549]
#   [0.23137255]
#   [0.24705882]]
#
#  [[0.35686275]
#   [0.36470588]
#   [0.34509804]
#   [0.39215686]
#   [0.40392157]
#   [0.3372549 ]
#   [0.29019608]
#   [0.21960784]
#   [0.36078431]
#   [0.41176471]
#   [0.39607843]
#   [0.40784314]
#   [0.38039216]
#   [0.41176471]
#   [0.22352941]
#   [0.35686275]
#   [0.49411765]
#   [0.70980392]
#   [0.77254902]
#   [0.67058824]
#   [0.75294118]
#   [0.70196078]
#   [0.72941176]
#   [0.81568627]
#   [0.67843137]
#   [0.79607843]
#   [0.2745098 ]
#   [0.25882353]]
#
#  [[0.27058824]
#   [0.27058824]
#   [0.24313725]
#   [0.29019608]
#   [0.29803922]
#   [0.28235294]
#   [0.29803922]
#   [0.34117647]
#   [0.15294118]
#   [0.26666667]
#   [0.30196078]
#   [0.27058824]
#   [0.2627451 ]
#   [0.29411765]
#   [0.24313725]
#   [0.29803922]
#   [0.23137255]
#   [0.23529412]
#   [0.3372549 ]
#   [0.3372549 ]
#   [0.32156863]
#   [0.28627451]
#   [0.29803922]
#   [0.2745098 ]
#   [0.25490196]
#   [0.25490196]
#   [0.26666667]
#   [0.25490196]]
#
#  [[0.28627451]
#   [0.30588235]
#   [0.34901961]
#   [0.30196078]
#   [0.33333333]
#   [0.28627451]
#   [0.29803922]
#   [0.3254902 ]
#   [0.28627451]
#   [0.29411765]
#   [0.28235294]
#   [0.2627451 ]
#   [0.2745098 ]
#   [0.28235294]
#   [0.2       ]
#   [0.24313725]
#   [0.23529412]
#   [0.25098039]
#   [0.23529412]
#   [0.19607843]
#   [0.19607843]
#   [0.19215686]
#   [0.17254902]
#   [0.05490196]
#   [0.14901961]
#   [0.10980392]
#   [0.0745098 ]
#   [0.04313725]]]
# 0

# %%
X=[]
Y=[]
start = 0
stop = total_row
X,Y=getData(start,stop)

# conversion into numpy array
X = np.array(X).reshape(-1, 28,28,1)
Y = np.array(Y)

# normalizing
X = X/255

# processing Y_train for dimension matching
Y = Y.reshape(len(X),)
# Out:
# Rejected Image: dec324bf-c2ff-4c7b-8d5a-96f17be58eb8.jpg

# %%
print('Image Data Shape: ',X.shape)
print('Label Data Shape: ',Y.shape)
# Out:
# Image Data Shape:  (4688, 28, 28, 1)
# Label Data Shape:  (4688,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.1, random_state = 500)
print('Train Image Data Shape: ',X_train.shape)
print('Train Label Data Shape: ',Y_train.shape)
print('Test Image Data Shape: ',X_test.shape)
print('Test Label Data Shape: ',Y_test.shape)
# Out:
# Train Image Data Shape:  (4219, 28, 28, 1)
# Train Label Data Shape:  (4219,)
# Test Image Data Shape:  (469, 28, 28, 1)
# Test Label Data Shape:  (469,)

# %%
X_train, X_validate, Y_train, Y_validate = train_test_split(X_train, Y_train, test_size = 0.1, random_state = 500)
print('Train Image Data Shape: ',X_train.shape)
print('Train Label Data Shape: ',Y_train.shape)
print('Validation Image Data Shape: ',X_validate.shape)
print('Validation Label Data Shape: ',Y_validate.shape)
# Out:
# Train Image Data Shape:  (3797, 28, 28, 1)
# Train Label Data Shape:  (3797,)
# Validation Image Data Shape:  (422, 28, 28, 1)
# Validation Label Data Shape:  (422,)

# %%
#CNN Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import os
import tensorflow as tf
import datetime, os
from tensorflow.keras.callbacks import TensorBoard

# %%
def build_model():
    cnn_model = Sequential()
    cnn_model.add(Conv2D(32, (3, 3), input_shape = (28,28,1), activation='relu'))
    cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
    cnn_model.add(Dropout(0.25))

    cnn_model.add(Conv2D(64, (3, 3), input_shape = (28,28,1), activation='relu'))
    cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
    cnn_model.add(Dropout(0.25))

    cnn_model.add(Conv2D(128, (3, 3), input_shape = (28,28,1), activation='relu'))
    cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
    cnn_model.add(Dropout(0.25))

    cnn_model.add(Flatten())
    cnn_model.add(Dense(units = 512, activation = 'relu'))
    cnn_model.add(Dropout(0.25))
    cnn_model.add(Dense(units = total_class, activation = 'softmax'))
    return cnn_model


model=build_model()
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  dropout (Dropout)           (None, 13, 13, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 5, 5, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 128)         73856
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 1, 1, 128)         0
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 512)               66048
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 20)                10260
#
# =================================================================
# Total params: 168,980
# Trainable params: 168,980
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def train_model(model):
    model.compile(loss ='sparse_categorical_crossentropy', optimizer='adam' ,metrics =['accuracy'])
    history = model.fit(X_train, Y_train, batch_size = 128, epochs = 100, verbose = 1, validation_data = (X_validate, Y_validate))
#     model.fit(X_train, Y_train, epochs=50, batch_size=512, validation_split=0.2)

train_model(model)
# Out:
# Epoch 1/100
# 33/33 [==============================] - 4s 71ms/step - loss: 2.6868 - accuracy: 0.1688 - val_loss: 2.6023 - val_accuracy: 0.2251
# Epoch 2/100
# 33/33 [==============================] - 2s 57ms/step - loss: 2.5973 - accuracy: 0.1998 - val_loss: 2.5297 - val_accuracy: 0.2441
# Epoch 3/100
# 33/33 [==============================] - 2s 55ms/step - loss: 2.4824 - accuracy: 0.2451 - val_loss: 2.3369 - val_accuracy: 0.3128
# Epoch 4/100
# 33/33 [==============================] - 2s 57ms/step - loss: 2.3559 - accuracy: 0.2840 - val_loss: 2.2025 - val_accuracy: 0.3578
# Epoch 5/100
# 33/33 [==============================] - 2s 57ms/step - loss: 2.2592 - accuracy: 0.3207 - val_loss: 2.1163 - val_accuracy: 0.3981
# Epoch 6/100
# 33/33 [==============================] - 2s 62ms/step - loss: 2.1834 - accuracy: 0.3508 - val_loss: 2.0123 - val_accuracy: 0.4289
# Epoch 7/100
# 33/33 [==============================] - 2s 68ms/step - loss: 2.1002 - accuracy: 0.3823 - val_loss: 1.9677 - val_accuracy: 0.4384
# Epoch 8/100
# 33/33 [==============================] - 2s 69ms/step - loss: 2.0236 - accuracy: 0.4027 - val_loss: 1.8461 - val_accuracy: 0.4787
# Epoch 9/100
# 33/33 [==============================] - 2s 71ms/step - loss: 1.9405 - accuracy: 0.4212 - val_loss: 1.7863 - val_accuracy: 0.4834
# Epoch 10/100
# 33/33 [==============================] - 2s 70ms/step - loss: 1.9078 - accuracy: 0.4316 - val_loss: 1.7303 - val_accuracy: 0.5118
# Epoch 11/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.8524 - accuracy: 0.4439 - val_loss: 1.6756 - val_accuracy: 0.5284
# Epoch 12/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.8010 - accuracy: 0.4733 - val_loss: 1.6242 - val_accuracy: 0.5095
# Epoch 13/100
# 33/33 [==============================] - 2s 71ms/step - loss: 1.7492 - accuracy: 0.4740 - val_loss: 1.5702 - val_accuracy: 0.5498
# Epoch 14/100
# 33/33 [==============================] - 2s 71ms/step - loss: 1.7119 - accuracy: 0.4873 - val_loss: 1.5539 - val_accuracy: 0.5474
# Epoch 15/100
# 33/33 [==============================] - 2s 70ms/step - loss: 1.6654 - accuracy: 0.4973 - val_loss: 1.4821 - val_accuracy: 0.5782
# Epoch 16/100
# 33/33 [==============================] - 2s 71ms/step - loss: 1.6415 - accuracy: 0.5070 - val_loss: 1.4217 - val_accuracy: 0.5877
# Epoch 17/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.5956 - accuracy: 0.5188 - val_loss: 1.3918 - val_accuracy: 0.5948
# Epoch 18/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.5713 - accuracy: 0.5215 - val_loss: 1.3537 - val_accuracy: 0.5972
# Epoch 19/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.5363 - accuracy: 0.5305 - val_loss: 1.3187 - val_accuracy: 0.6256
# Epoch 20/100
# 33/33 [==============================] - 2s 66ms/step - loss: 1.5133 - accuracy: 0.5331 - val_loss: 1.2525 - val_accuracy: 0.6327
# Epoch 21/100
# 33/33 [==============================] - 2s 64ms/step - loss: 1.4897 - accuracy: 0.5430 - val_loss: 1.2325 - val_accuracy: 0.6351
# Epoch 22/100
# 33/33 [==============================] - 2s 65ms/step - loss: 1.4609 - accuracy: 0.5558 - val_loss: 1.2671 - val_accuracy: 0.6209
# Epoch 23/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.4366 - accuracy: 0.5591 - val_loss: 1.1789 - val_accuracy: 0.6611
# Epoch 24/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.4168 - accuracy: 0.5572 - val_loss: 1.1443 - val_accuracy: 0.6659
# Epoch 25/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.4080 - accuracy: 0.5632 - val_loss: 1.1164 - val_accuracy: 0.6801
# Epoch 26/100
# 33/33 [==============================] - 2s 66ms/step - loss: 1.3435 - accuracy: 0.5859 - val_loss: 1.0970 - val_accuracy: 0.6801
# Epoch 27/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.3495 - accuracy: 0.5831 - val_loss: 1.0671 - val_accuracy: 0.6872
# Epoch 28/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.3169 - accuracy: 0.5942 - val_loss: 1.0458 - val_accuracy: 0.6872
# Epoch 29/100
# 33/33 [==============================] - 2s 65ms/step - loss: 1.3183 - accuracy: 0.5859 - val_loss: 0.9917 - val_accuracy: 0.7275
# Epoch 30/100
# 33/33 [==============================] - 2s 66ms/step - loss: 1.2777 - accuracy: 0.5992 - val_loss: 0.9537 - val_accuracy: 0.7204
# Epoch 31/100
# 33/33 [==============================] - 2s 66ms/step - loss: 1.2636 - accuracy: 0.6058 - val_loss: 0.9417 - val_accuracy: 0.7370
# Epoch 32/100
# 33/33 [==============================] - 2s 66ms/step - loss: 1.2478 - accuracy: 0.6153 - val_loss: 0.9365 - val_accuracy: 0.7156
# Epoch 33/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.2420 - accuracy: 0.6106 - val_loss: 0.9091 - val_accuracy: 0.7322
# Epoch 34/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.2130 - accuracy: 0.6227 - val_loss: 0.8758 - val_accuracy: 0.7417
# Epoch 35/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.1909 - accuracy: 0.6257 - val_loss: 0.8550 - val_accuracy: 0.7536
# Epoch 36/100
# 33/33 [==============================] - 2s 64ms/step - loss: 1.1875 - accuracy: 0.6274 - val_loss: 0.8308 - val_accuracy: 0.7536
# Epoch 37/100
# 33/33 [==============================] - 2s 66ms/step - loss: 1.1647 - accuracy: 0.6362 - val_loss: 0.8140 - val_accuracy: 0.7630
# Epoch 38/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.1356 - accuracy: 0.6402 - val_loss: 0.7721 - val_accuracy: 0.7820
# Epoch 39/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.1227 - accuracy: 0.6404 - val_loss: 0.7708 - val_accuracy: 0.7938
# Epoch 40/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.1214 - accuracy: 0.6433 - val_loss: 0.7833 - val_accuracy: 0.7773
# Epoch 41/100
# 33/33 [==============================] - 2s 66ms/step - loss: 1.1041 - accuracy: 0.6428 - val_loss: 0.7303 - val_accuracy: 0.8057
# Epoch 42/100
# 33/33 [==============================] - 2s 71ms/step - loss: 1.0976 - accuracy: 0.6518 - val_loss: 0.7210 - val_accuracy: 0.8057
# Epoch 43/100
# 33/33 [==============================] - 2s 66ms/step - loss: 1.0840 - accuracy: 0.6556 - val_loss: 0.6933 - val_accuracy: 0.8104
# Epoch 44/100
# 33/33 [==============================] - 2s 65ms/step - loss: 1.0573 - accuracy: 0.6625 - val_loss: 0.6658 - val_accuracy: 0.8294
# Epoch 45/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.0581 - accuracy: 0.6592 - val_loss: 0.6658 - val_accuracy: 0.8128
# Epoch 46/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.0377 - accuracy: 0.6670 - val_loss: 0.6525 - val_accuracy: 0.8199
# Epoch 47/100
# 33/33 [==============================] - 2s 66ms/step - loss: 1.0244 - accuracy: 0.6772 - val_loss: 0.6396 - val_accuracy: 0.8294
# Epoch 48/100
# 33/33 [==============================] - 2s 68ms/step - loss: 0.9939 - accuracy: 0.6867 - val_loss: 0.6152 - val_accuracy: 0.8341
# Epoch 49/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.0106 - accuracy: 0.6698 - val_loss: 0.5964 - val_accuracy: 0.8294
# Epoch 50/100
# 33/33 [==============================] - 2s 66ms/step - loss: 0.9656 - accuracy: 0.6831 - val_loss: 0.5672 - val_accuracy: 0.8507
# Epoch 51/100
# 33/33 [==============================] - 2s 65ms/step - loss: 0.9456 - accuracy: 0.6980 - val_loss: 0.5598 - val_accuracy: 0.8483
# Epoch 52/100
# 33/33 [==============================] - 2s 67ms/step - loss: 0.9375 - accuracy: 0.7085 - val_loss: 0.5462 - val_accuracy: 0.8483
# Epoch 53/100
# 33/33 [==============================] - 2s 68ms/step - loss: 0.9318 - accuracy: 0.6954 - val_loss: 0.5252 - val_accuracy: 0.8555
# Epoch 54/100
# 33/33 [==============================] - 2s 68ms/step - loss: 0.9390 - accuracy: 0.6959 - val_loss: 0.5112 - val_accuracy: 0.8720
# Epoch 55/100
# 33/33 [==============================] - 2s 70ms/step - loss: 0.9223 - accuracy: 0.7056 - val_loss: 0.5069 - val_accuracy: 0.8720
# Epoch 56/100
# 33/33 [==============================] - 2s 69ms/step - loss: 0.8947 - accuracy: 0.7108 - val_loss: 0.5054 - val_accuracy: 0.8744
# Epoch 57/100
# 33/33 [==============================] - 2s 65ms/step - loss: 0.9085 - accuracy: 0.7051 - val_loss: 0.4921 - val_accuracy: 0.8815
# Epoch 58/100
# 33/33 [==============================] - 2s 66ms/step - loss: 0.8876 - accuracy: 0.7142 - val_loss: 0.4803 - val_accuracy: 0.8815
# Epoch 59/100
# 33/33 [==============================] - 2s 67ms/step - loss: 0.8658 - accuracy: 0.7172 - val_loss: 0.4632 - val_accuracy: 0.8839
# Epoch 60/100
# 33/33 [==============================] - 2s 67ms/step - loss: 0.8652 - accuracy: 0.7168 - val_loss: 0.4316 - val_accuracy: 0.8981
# Epoch 61/100
# 33/33 [==============================] - 2s 66ms/step - loss: 0.8681 - accuracy: 0.7168 - val_loss: 0.4271 - val_accuracy: 0.8934
# Epoch 62/100
# 33/33 [==============================] - 2s 66ms/step - loss: 0.8315 - accuracy: 0.7281 - val_loss: 0.4176 - val_accuracy: 0.8934
# Epoch 63/100
# 33/33 [==============================] - 2s 70ms/step - loss: 0.8243 - accuracy: 0.7374 - val_loss: 0.4170 - val_accuracy: 0.8886
# Epoch 64/100
# 33/33 [==============================] - 2s 66ms/step - loss: 0.8125 - accuracy: 0.7336 - val_loss: 0.4229 - val_accuracy: 0.8981
# Epoch 65/100
# 33/33 [==============================] - 2s 64ms/step - loss: 0.8357 - accuracy: 0.7291 - val_loss: 0.4048 - val_accuracy: 0.8934
# Epoch 66/100
# 33/33 [==============================] - 2s 67ms/step - loss: 0.7940 - accuracy: 0.7402 - val_loss: 0.3820 - val_accuracy: 0.9076
# Epoch 67/100
# 33/33 [==============================] - 2s 68ms/step - loss: 0.7960 - accuracy: 0.7443 - val_loss: 0.3775 - val_accuracy: 0.9005
# Epoch 68/100
# 33/33 [==============================] - 2s 67ms/step - loss: 0.7833 - accuracy: 0.7438 - val_loss: 0.3703 - val_accuracy: 0.9028
# Epoch 69/100
# 33/33 [==============================] - 2s 67ms/step - loss: 0.7710 - accuracy: 0.7421 - val_loss: 0.3514 - val_accuracy: 0.9147
# Epoch 70/100
# 33/33 [==============================] - 2s 67ms/step - loss: 0.7652 - accuracy: 0.7514 - val_loss: 0.3641 - val_accuracy: 0.9052
# Epoch 71/100
# 33/33 [==============================] - 2s 65ms/step - loss: 0.7799 - accuracy: 0.7452 - val_loss: 0.3504 - val_accuracy: 0.9171
# Epoch 72/100
# 33/33 [==============================] - 2s 65ms/step - loss: 0.7447 - accuracy: 0.7525 - val_loss: 0.3300 - val_accuracy: 0.9242
# Epoch 73/100
# 33/33 [==============================] - 2s 67ms/step - loss: 0.7715 - accuracy: 0.7469 - val_loss: 0.3176 - val_accuracy: 0.9218
# Epoch 74/100
# 33/33 [==============================] - 2s 67ms/step - loss: 0.7589 - accuracy: 0.7542 - val_loss: 0.3173 - val_accuracy: 0.9218
# Epoch 75/100
# 33/33 [==============================] - 2s 66ms/step - loss: 0.7136 - accuracy: 0.7618 - val_loss: 0.2992 - val_accuracy: 0.9313
# Epoch 76/100
# 33/33 [==============================] - 2s 65ms/step - loss: 0.7191 - accuracy: 0.7639 - val_loss: 0.3081 - val_accuracy: 0.9147
# Epoch 77/100
# 33/33 [==============================] - 2s 66ms/step - loss: 0.6969 - accuracy: 0.7765 - val_loss: 0.2814 - val_accuracy: 0.9289
# Epoch 78/100
# 33/33 [==============================] - 2s 70ms/step - loss: 0.7014 - accuracy: 0.7701 - val_loss: 0.2907 - val_accuracy: 0.9384
# Epoch 79/100
# 33/33 [==============================] - 2s 67ms/step - loss: 0.7314 - accuracy: 0.7537 - val_loss: 0.2857 - val_accuracy: 0.9265
# Epoch 80/100
# 33/33 [==============================] - 2s 67ms/step - loss: 0.6840 - accuracy: 0.7732 - val_loss: 0.2690 - val_accuracy: 0.9289
# Epoch 81/100
# 33/33 [==============================] - 2s 67ms/step - loss: 0.6679 - accuracy: 0.7798 - val_loss: 0.2485 - val_accuracy: 0.9360
# Epoch 82/100
# 33/33 [==============================] - 2s 67ms/step - loss: 0.6807 - accuracy: 0.7753 - val_loss: 0.2620 - val_accuracy: 0.9289
# Epoch 83/100
# 33/33 [==============================] - 2s 69ms/step - loss: 0.6808 - accuracy: 0.7710 - val_loss: 0.2465 - val_accuracy: 0.9384
# Epoch 84/100
# 33/33 [==============================] - 2s 74ms/step - loss: 0.6808 - accuracy: 0.7741 - val_loss: 0.2473 - val_accuracy: 0.9408
# Epoch 85/100
# 33/33 [==============================] - 2s 71ms/step - loss: 0.6724 - accuracy: 0.7803 - val_loss: 0.2270 - val_accuracy: 0.9573
# Epoch 86/100
# 33/33 [==============================] - 2s 68ms/step - loss: 0.6688 - accuracy: 0.7781 - val_loss: 0.2312 - val_accuracy: 0.9455
# Epoch 87/100
# 33/33 [==============================] - 2s 64ms/step - loss: 0.6495 - accuracy: 0.7869 - val_loss: 0.2191 - val_accuracy: 0.9526
# Epoch 88/100
# 33/33 [==============================] - 2s 70ms/step - loss: 0.6420 - accuracy: 0.7869 - val_loss: 0.2265 - val_accuracy: 0.9526
# Epoch 89/100
# 33/33 [==============================] - 2s 66ms/step - loss: 0.6467 - accuracy: 0.7850 - val_loss: 0.2180 - val_accuracy: 0.9597
# Epoch 90/100
# 33/33 [==============================] - 2s 67ms/step - loss: 0.6509 - accuracy: 0.7838 - val_loss: 0.2035 - val_accuracy: 0.9597
# Epoch 91/100
# 33/33 [==============================] - 2s 68ms/step - loss: 0.6360 - accuracy: 0.7940 - val_loss: 0.2145 - val_accuracy: 0.9573
# Epoch 92/100
# 33/33 [==============================] - 2s 68ms/step - loss: 0.6387 - accuracy: 0.7857 - val_loss: 0.2060 - val_accuracy: 0.9597
# Epoch 93/100
# 33/33 [==============================] - 2s 66ms/step - loss: 0.6292 - accuracy: 0.7957 - val_loss: 0.2048 - val_accuracy: 0.9597
# Epoch 94/100
# 33/33 [==============================] - 2s 65ms/step - loss: 0.6164 - accuracy: 0.7983 - val_loss: 0.1971 - val_accuracy: 0.9550
# Epoch 95/100
# 33/33 [==============================] - 2s 66ms/step - loss: 0.6066 - accuracy: 0.7943 - val_loss: 0.1796 - val_accuracy: 0.9668
# Epoch 96/100
# 33/33 [==============================] - 2s 66ms/step - loss: 0.6104 - accuracy: 0.7983 - val_loss: 0.1724 - val_accuracy: 0.9621
# Epoch 97/100
# 33/33 [==============================] - 2s 70ms/step - loss: 0.6373 - accuracy: 0.7898 - val_loss: 0.1779 - val_accuracy: 0.9621
# Epoch 98/100
# 33/33 [==============================] - 2s 68ms/step - loss: 0.5646 - accuracy: 0.8116 - val_loss: 0.1670 - val_accuracy: 0.9739
# Epoch 99/100
# 33/33 [==============================] - 2s 67ms/step - loss: 0.5850 - accuracy: 0.8052 - val_loss: 0.1910 - val_accuracy: 0.9455
# Epoch 100/100
# 33/33 [==============================] - 2s 67ms/step - loss: 0.5938 - accuracy: 0.8040 - val_loss: 0.1638 - val_accuracy: 0.9692

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.plot(model.history.history['loss'], label='Loss')
# plt.plot(model.history.history['val_loss'], label='val_Loss')
plt.legend()
plt.grid()
plt.title('Loss evolution')

plt.subplot(2, 2, 2)
plt.plot(model.history.history['accuracy'], label='accuracy')
# plt.plot(model.history.history['val_accuracy'], label='val_accuracy')
plt.legend()
plt.grid()
plt.title('Accuracy evolution')
# Out:
# Text(0.5, 1.0, 'Accuracy evolution')

# %%
from keras import models
model = models.load_model('visual_product_recommend.h5')

# %%
model.save('visual_product_recommend.h5')

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
#predicted_classes = model.predict_classes(X_test)
predict_x=model.predict(X_test) 
predicted_classes=np.argmax(predict_x,axis=1)
# Out:
# 15/15 [==============================] - 0s 4ms/step

# %%
#PC=PredictedClass #TC=TrueClass
L = 5
W = 5
fig, axes = plt.subplots(L, W, figsize = (12,12))
axes = axes.ravel()

for i in np.arange(0, L * W):  
    axes[i].imshow(X_test[i].reshape(28,28))
    axes[i].set_title(f"PC = {unique_types[predicted_classes[i]]}\n TC = {unique_types[Y_test[i]]}") #predicted_classes[i]:0.1f #Y_test[i]:0.1f
    axes[i].axis('off')
plt.subplots_adjust(wspace=0.5)

# %%
#Dataframe.head(10)
def load_image(i):
    Image_path=DATASET_PATH+list_directory[index]+"/"+Dataframe.loc[i,'image_name']
    Image_id=Dataframe.loc[i,'image_name'].split(".")
    res=Image_id[0]
    image = cv2.imread(Image_path,cv2.IMREAD_COLOR)
    resized_img = cv2.resize(image, dsize=(224, 224))
    return resized_img,res
img,img_id = load_image(4200)
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.title(img_id)
plt.imshow(img)

# %%
def make_prediction(img):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
    resized_img = cv2.resize(img, dsize=(28, 28))
    x_data = np.array(resized_img).reshape(-1, 28,28,1)
    x_data=x_data/255
#     print(x_data)
#     print(x_data.shape)
    result=model.predict(x_data)
#     print(type(result))
#     print(np.argmax(result))
    return x_data,unique_types[np.argmax(result)]

numpy_image,result=make_prediction(img)
print(result)
# Out:
# 1/1 [==============================] - 0s 28ms/step
# Pants

# %%
typeList=[]
for i, row in df.iterrows(): 
    if(row["label"]==result):
        #print(row["id"],row["articleType"])
        if(img_id!=str(row["image"])):
            typeList.append(row['image'])
            #typeList.append(row['label'])
            
            
print(typeList)
# Out:
# ['002eb5b8-6541-42a3-9596-0d94f7b866ae', '0098b991-e36e-4ef1-b5ee-4154b21e2a92', '01033304-f9a4-48c4-af65-677512880fae', '012d1ca9-baaf-4b01-8b60-955f3408b1b7', '0237ad41-08b8-474e-9ba2-7fc342e6b8db', '0257eb81-f3d3-4704-8299-8b6ab20f1ed4', '027a10cb-97f0-46f3-b670-611e481bb8fe', '027c81f2-c6e1-498a-8f69-823ce631438e', '030a5708-f6d7-441f-86ee-0b51b33f3f51', '03229a43-ab8f-4fdc-ae53-75d64d300b44', '03383314-4e34-4604-8ba0-f5d75371204f', '03a43dea-405e-4a11-9716-2f790a95f699', '03b5fa92-c65d-4b45-820b-967e85f41ee2', '041cea74-d96a-45ff-a8e2-d311ee0f21d8', '046b4028-ff00-4df3-a69e-d652c357e497', '046d0a65-f5a6-47f6-afaf-e692bfcfcb00', '0577a46b-53d1-4de1-a0e9-bec8992a6f59', '05814dc4-0520-47e6-91e0-402a971ba40a', '05e280ef-53d9-497f-be09-e83c549f0a14', '062752a8-2cbd-434f-b850-4a4f85c32cb3', '06697086-d232-4c13-a5ea-ebd759b53bc6', '07203b6c-8d84-4a31-ac32-78b0a66de843', '073f2d48-e363-474d-acbe-11103356e7e2', '07b616c7-1ac6-48ea-8517-f0bc8d4ad4ec', '081b5ec1-13a6-43c8-991f-9ad2020f646a', '08973288-3d8b-4c07-9f2d-ce1392da54be', '08f602bc-a030-4f73-b0fb-0ddd986840aa', '0982f691-f2ce-469b-b81e-6842b914632c', '09cd286c-0fab-45b9-9152-322f32275ef7', '0a2668d3-e42a-4f46-bb7f-01cc409c1839', '0a7e5fe0-d592-40e6-b9b8-75aac9a2d685', '0ad5bfb5-0f2b-4396-8c05-39ca0a9a2960', '0c224954-0e0f-4caa-82c8-cf9581e89336', '0c2eb9ff-7f26-492d-9957-0d845669685f', '0c99f0b4-3a0d-4d24-bfdd-e9e98914892c', '0ccc318a-7d69-4d7f-a442-aac1f88bc453', '0d0bb91d-01d7-45df-827d-da96bbc44b15', '0d0c2308-2c58-4e38-90c1-c893358b5f86', '0db5a848-2066-436f-bd21-8b3585b391a5', '0dfec862-c49f-430b-a6ef-c7ceb187225e', '0e27351a-13d0-41a6-b731-4090b368d656', '0e3d71f8-7677-4cd4-ba24-4788c3890ac1', '0e684087-83bf-4153-90f4-6f7ba6f25338', '0fe5eeb6-316f-4f60-b604-8a1b25e23433', '1015f2a4-265d-4d43-b697-17c5735cf46d', '102a92cc-2886-4265-90ac-30d00173435b', '103926d8-d84b-4cc4-97c9-2bdb9b82f728', '1042a9df-2411-4f6c-b156-1d0d94e2f6ed', '10f4ac8d-9d8d-4a59-88dc-5e085d61aa48', '10fb1c4a-a2ab-4f43-848e-d8a1a41dff8c', '119518b0-abfc-49a1-88dc-016f2dbd17ff', '11aa05f3-ac70-490a-9e87-4de486ede646', '122f0c94-4f37-4010-8c43-06d79bdf4433', '1284316a-8db1-450c-bb64-4929f16d91ca', '129287b2-e3ab-45f8-b0aa-cd0fa1e6864c', '12a89984-f366-4020-9eeb-922c00127951', '12bfe0f0-accc-4539-ab51-53f63534938e', '12f7dcc1-a830-4a57-8d6e-088cb0ae4d08', '137ef939-62db-460f-9102-120dc1ffeeec', '13def0b2-758f-4640-8563-15809bd8abf5', '1417a51e-fca6-458d-9d7c-456644616663', '143ea97f-a2fd-4a68-851d-a31e5ba8a92b', '145789f9-6d4e-4e63-a4da-6ea78302d739', '14625df7-84a3-435c-90a7-e57a9dce3888', '1490d841-c8de-433d-8a58-7c840c2f24a0', '14bc842c-60e9-468c-ab35-5089143945f5', '1551ffd7-fc12-4e86-8d46-a435cbe311b0', '1559340f-aa0c-409a-8ac2-fc7e1a5b6c22', '15a1e02b-ad2a-4b9f-9d44-0e4d260594a8', '15a7641e-e098-4015-952f-4e8c103b69e6', '15eea7e2-3dba-4f28-a34e-5e72e5a8a42f', '161964e5-6633-48b1-bfaf-1909e3656d19', '16edcd9e-82d9-4827-88d0-32c10298adea', '16f2e166-c38a-4171-a5b2-e9f5c55fafc3', '173a13ad-affd-4406-803a-643ee75cd029', '17936ba2-937a-46d8-afa0-0750abdb3200', '17bebe65-17cc-42b3-885f-4e6c64a16f26', '184b54b9-94f1-41c6-9aeb-64efa09a4720', '188eaa2d-1a69-49b1-a9fb-7b3789ac93b4', '18a573de-219f-44de-8dc9-0a64422e4f99', '1911309c-7ff5-456e-a3de-d3dd9de4c7bc', '19931b17-d23d-4b7a-91f8-ca5cbebf8a7c', '19ff0603-c52b-4d27-a9b9-cfd9da5e9f35', '1a08f33a-2ff4-4fb8-920b-8ff514bcdda8', '1b065c3c-0679-40af-9924-8de9986fdf66', '1b5f2882-e33e-4efc-b469-bcf87b9f53ed', '1bb71a5d-a665-4d72-9e06-b7892a8a7e92', '1c9a6bc0-d29e-4e2b-8d00-d19e4d77a380', '1ca03195-b1e8-4c47-85de-81a942ea561e', '1caba263-088a-448a-be6d-30072c29af09', '1ccfcad0-57a3-44a6-83f7-f42a189cf6bf', '1d226430-72e6-4be7-998e-604df0fae43d', '1d3e7e1d-6f5a-4a99-8a74-15e007d144f4', '1d407629-87e5-4702-b9fc-e3b19de93570', '1d42c614-19d5-4515-8ef9-0bf551a601c0', '1e9ba1e2-eefe-4853-ab05-63598cb144f1', '1ed97cea-53f2-4342-8ac2-9083c936eef6', '1f3fe0f5-4724-43f8-bfce-6e22d1f1f5ba', '1faab1ac-d8d4-4711-adbb-7812d7513d41', '201d7c0c-4e6f-47c9-bb55-44890164c6a7', ...

# %%
i=0
X_similar=[]
X_id_similar=[]
X_numpy=[]
for imageId in typeList:
#     print(imageId)
    Image_path=DATASET_PATH+list_directory[index]+"/"+str(imageId)+".jpg"
    image = cv2.imread(Image_path,cv2.IMREAD_GRAYSCALE)
    try:
        resized_img = cv2.resize(image, dsize=(28,28))
    except:
        print("can't read file: ", str(imageId)+".jpg")
    X_similar.append(resized_img)
    X_id_similar.append(imageId)
        
X_numpy = np.array(X_similar).reshape(-1, 28,28,1)
X_numpy = X_numpy/255
#print(X_numpy[0])

plt.imshow(X_similar[0])
plt.title(X_id_similar[0])
# Out:
# Text(0.5, 1.0, '002eb5b8-6541-42a3-9596-0d94f7b866ae')

# %%
#Recommendation
import math
def calculateDistance(i1, i2):
    return math.sqrt(np.sum((i1-i2)**2))

print(calculateDistance(numpy_image,X_numpy[0]))
# Out:
# 11.127422475561659

# %%
distance_list=[]
for i in range (0, len(X_numpy)):
    distance_list.append(calculateDistance(numpy_image,X_numpy[i]))

sorted_distance_list=distance_list.copy()
#print(distance_list)
sorted_distance_list.sort()

least_ten_distance=sorted_distance_list[0:10]
print(least_ten_distance)
index_distance=[]
for i in range (0, len(least_ten_distance)-1):
    if(least_ten_distance[i]!=least_ten_distance[i+1]):
        index_distance.append(distance_list.index(least_ten_distance[i]))

index_distance=index_distance[0:5]

print(index_distance)
# Out:
# [3.773009633125399, 3.8231472911117086, 4.1535354793338835, 4.350872145619528, 4.748632616475939, 4.751035015425675, 4.759726277107467, 4.803390126666591, 4.809816311343482, 4.840345309411369]
# [523, 78, 512, 491, 355]

# %%
# Image_path=DATASET_PATH+list_directory[index]+"/"+str(img_id)+".jpg"
# src = cv2.imread(Image_path)
# image = cv2.cvtColor(src, cv2.COLOR_BGR2RGB) 
plt.imshow(img)
plt.title(img_id)

fig=plt.figure()
fig.set_figheight(15)
fig.set_figwidth(15)
axis=[]
for i in range(0,len(index_distance)):
    print(X_id_similar[i])
    Image_path=DATASET_PATH+list_directory[index]+"/"+str(X_id_similar[index_distance[i]])+".jpg"
    src = cv2.imread(Image_path)
    image = cv2.cvtColor(src, cv2.COLOR_BGR2RGB) 
    axis.append(fig.add_subplot(1,5, i+1))
    subplot_title=str(X_id_similar[index_distance[i]])
    axis[-1].set_title(subplot_title)  
    plt.imshow(image)
    
fig.tight_layout()
plt.show()
# Out:
# 002eb5b8-6541-42a3-9596-0d94f7b866ae
# 0098b991-e36e-4ef1-b5ee-4154b21e2a92
# 01033304-f9a4-48c4-af65-677512880fae
# 012d1ca9-baaf-4b01-8b60-955f3408b1b7
# 0237ad41-08b8-474e-9ba2-7fc342e6b8db
